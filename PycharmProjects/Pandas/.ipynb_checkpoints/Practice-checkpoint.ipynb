# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Arian\Desktop\Programming\Python\PycharmProjects\Pandas\pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1', 'Type 2']]
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.iloc[795]
# Out:
# #                 719
# Name          Diancie
# Type 1           Rock
# Type 2          Fairy
# HP                 50
# Attack            100
# Defense           150
# Sp. Atk           100
# Sp. Def           150
# Speed              50
# Generation          6
# Legendary        True
# Name: 795, dtype: object

# %%
df.iloc[795][1]
# Out:
# 'Diancie'

# %%
df.iloc[[795,799]]
# Out:
#        #       Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 795  719    Diancie   Rock  Fairy  50     100      150      100      150
# 799  721  Volcanion   Fire  Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# 795     50           6       True
# 799     70           6       True

# %%
df.loc[df['Type 2']=='Water']
# Out:
#        #             Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  \
# 149  138          Omanyte      Rock  Water   35      40      100       90
# 150  139          Omastar      Rock  Water   70      60      125      115
# 151  140           Kabuto      Rock  Water   30      80       90       55
# 152  141         Kabutops      Rock  Water   60     115      105       65
# 307  283          Surskit       Bug  Water   40      30       32       50
# 398  363           Spheal       Ice  Water   70      40       50       55
# 399  364           Sealeo       Ice  Water   90      60       70       75
# 400  365          Walrein       Ice  Water  110      80       90       95
# 445  400          Bibarel    Normal  Water   79      85       60       55
# 533  479  RotomWash Rotom  Electric  Water   50      65      107      105
# 758  688          Binacle      Rock  Water   42      52       67       39
# 759  689       Barbaracle      Rock  Water   72     105      115       54
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('HP', ascending=False)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.to_csv(r'C:\Users\Arian\Desktop\Programming\Python\PycharmProjects\Pandas\modified_pokemon_data.csv', index=False)

# %%
df.to_excel(r'C:\Users\Arian\Desktop\Programming\Python\PycharmProjects\Pandas\modified_pokemon_data.xlsx', index=False)

# %%
new_df = df.loc[((df['Type 1']=='Grass') | (df['Type 2']=='Fairy')) & (df['HP'] > 70) & (df['Speed'] > 70)]
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#       #                   Name  Type 1    Type 2  Total   HP  Attack  Defense  \
# 0     3               Venusaur   Grass    Poison    525   80      82       83
# 1     3  VenusaurMega Venusaur   Grass    Poison    625   80     100      123
# 2   154               Meganium   Grass       NaN    525   80      82      100
# 3   189               Jumpluff   Grass    Flying    460   75      55       70
# 4   275                Shiftry   Grass      Dark    480   90     100       60
# 5   334    AltariaMega Altaria  Dragon     Fairy    590   75     110      110
# 6   492      ShayminLand Forme   Grass       NaN    600  100     100      100
# 7   492       ShayminSky Forme   Grass    Flying    600  100     103       75
# 8   497              Serperior   Grass       NaN    528   75      75       95
# 9   512               Simisage   Grass       NaN    498   75      98       63
# 10  640               Virizion   Grass  Fighting    580   91      90       72
#
# ...

# %%
new_df.loc[~new_df['Name'].str.contains('Mega')]
# Out:
#       #               Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0     3           Venusaur  Grass    Poison    525   80      82       83
# 3   189           Jumpluff  Grass    Flying    460   75      55       70
# 4   275            Shiftry  Grass      Dark    480   90     100       60
# 6   492  ShayminLand Forme  Grass       NaN    600  100     100      100
# 7   492   ShayminSky Forme  Grass    Flying    600  100     103       75
# 8   497          Serperior  Grass       NaN    528   75      75       95
# 9   512           Simisage  Grass       NaN    498   75      98       63
# 10  640           Virizion  Grass  Fighting    580   91      90       72
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       100      100     80           1      False
# 3        55       95    110           2      False
# 4        90       60     80           3      False
# 6       100      100    100           4       True
# 7       120       75    127           4       True
# ...

# %%
new_df.loc[new_df['Type 1'] == 'Grass', 'Speed'] = '200'
new_df
# Out:
#       #                   Name  Type 1    Type 2  Total   HP  Attack  Defense  \
# 0     3               Venusaur   Grass    Poison    525   80      82       83
# 1     3  VenusaurMega Venusaur   Grass    Poison    625   80     100      123
# 2   154               Meganium   Grass       NaN    525   80      82      100
# 3   189               Jumpluff   Grass    Flying    460   75      55       70
# 4   275                Shiftry   Grass      Dark    480   90     100       60
# 5   334    AltariaMega Altaria  Dragon     Fairy    590   75     110      110
# 6   492      ShayminLand Forme   Grass       NaN    600  100     100      100
# 7   492       ShayminSky Forme   Grass    Flying    600  100     103       75
# 8   497              Serperior   Grass       NaN    528   75      75       95
# 9   512               Simisage   Grass       NaN    498   75      98       63
# 10  640               Virizion   Grass  Fighting    580   91      90       72
#
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# ...

# %%
df.groupby(['Type 2']).sum()
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# Bug        1146   1180   160     270      240      140      185    185
# Dark       8277   9688  1511    2196     1441     1636     1397   1507
# Dragon     8686   9471  1479    1700     1567     1773     1502   1450
# Electric   2794   2732   529     436      410      487      441    429
# Fairy      8718   9613  1479    1417     1699     1725     1885   1408
# Fighting  11393  13672  2066    2934     2145     2113     2142   2272
# Fire       5782   6075   855     975      962     1325     1002    956
# Flying    32117  43897  6925    7788     6626     7336     6907   8315
# Ghost      7724   6030   828    1178     1152     1025     1093    754
# Grass     12635  10223  1566    1854     2003     1504     1863   1433
# Ground    10766  15552  2703    3145     3161     2294     2336   1913
# Ice        6178   7360  1260    1372     1199     1297     1187   1045
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
df['count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# C:\Users\Arian\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
A = pd.Series([2, 3, 4, 5], index=['a', 'b', 'c', 'd'])
A
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
A.values
# Out:
# array([2, 3, 4, 5], dtype=int64)

# %%
type(A.values)
# Out:
# numpy.ndarray

# %%
A.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
A['a':'d']
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64

# %%
grades_dict = {'A':4,'B':3.5,'C':3,'D':2.5}
grades = pd.Series(grades_dict)
grades
# Out:
# A    4.0
# B    3.5
# C    3.0
# D    2.5
# dtype: float64

# %%
marks_dict = {'A':85,'B':75,'C':65,'D':55}
marks = pd.Series(marks_dict)
marks
# Out:
# A    85
# B    75
# C    65
# D    55
# dtype: int64

# %%
marks['A']
# Out:
# 85

# %%
marks[0:2]
# Out:
# A    85
# B    75
# dtype: int64

# %%
df = pd.DataFrame({'Marks':marks, 'Grades':grades})
df
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5
# C     65     3.0
# D     55     2.5

# %%
df.values[0,0]
# Out:
# 85.0

# %%
df.iloc[0,0]
# Out:
# 85

# %%
df['ScaledMarks'] = 100*(df['Marks']/90)
df
# Out:
#    Marks  Grades  ScaledMarks
# A     85     4.0    94.444444
# B     75     3.5    83.333333
# C     65     3.0    72.222222
# D     55     2.5    61.111111

# %%
del df['ScaledMarks']
# or df.drop(columns=['ScaledMarks'])

# %%
df
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5
# C     65     3.0
# D     55     2.5

# %%
df[df['Grades']<3.2]
# Out:
#    Marks  Grades
# C     65     3.0
# D     55     2.5

# %%
A = pd.DataFrame([{'a':1,'b':4},{'b':-3,'c':9}])
A
# Out:
#      a  b    c
# 0  1.0  4  NaN
# 1  NaN -3  9.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  1.0  4  0.0
# 1  0.0 -3  9.0

# %%
values = {'a':'😀','c':'😱'}
A.fillna(value=values)
# Out:
#    a  b  c
# 0  1  4  😱
# 1  😀 -3  9

# %%
B = pd.Series(['a','b','c'], index=[1,3,5])
B
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
B[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
B.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
B.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)
plt.plot(x,y)

# %%
plt.scatter(x[::30],y[::30])
